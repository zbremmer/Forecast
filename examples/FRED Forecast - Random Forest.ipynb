# %% [markdown]
# ## GDP Forecast Example
# This notebook provides an example of using the forecast package to predict US GDP values.

# %%
# Import packages
import pandas as pd

# %matplotlib inline

# %%
df = pd.read_csv("GDP.csv", index_col='DATE')

# Convert index to datetime and change target col name to y
df.index = pd.to_datetime(df.index)
df.columns = ['y']

# %%
df.plot()
